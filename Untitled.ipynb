# %%
import pandas as pd

# %%
df = pd.read_csv('Crop_per_month_egypt_2010.csv')

# %%
df1 = df.fillna(0)
print(df1)
# Out:
#                            area(1000 ha)    Jan 2010   Feb 2010   March 2010   \
# Wheat                               1 261        35.0       35.0         35.0
# Rice                                  452         0.0        0.0          0.0
# Maize                                 927         0.0        0.0          0.0
# Other cereals                         351        10.0       10.0         10.0
# Vegetables one                        388         0.0        0.0          0.0
# Vegetables two                        388         0.0        0.0          0.0
# Fruits                                389        11.0       11.0         11.0
# Mangoes                                64         2.0        2.0          2.0
# Figs                                   32         1.0        1.0          1.0
# Dates                                  42         1.0        1.0          1.0
# Citrus                                157         4.0        4.0          4.0
# ...

# %%
df1.dropna()
# Out:
#                            area(1000 ha)    Jan 2010   Feb 2010   March 2010   \
# Wheat                               1 261        35.0       35.0         35.0
# Rice                                  452         0.0        0.0          0.0
# Maize                                 927         0.0        0.0          0.0
# Other cereals                         351        10.0       10.0         10.0
# Vegetables one                        388         0.0        0.0          0.0
# Vegetables two                        388         0.0        0.0          0.0
# Fruits                                389        11.0       11.0         11.0
# Mangoes                                64         2.0        2.0          2.0
# Figs                                   32         1.0        1.0          1.0
# Dates                                  42         1.0        1.0          1.0
# Citrus                                157         4.0        4.0          4.0
# ...

# %%
df1.transpose().head()
# Out:
#                 Wheat  Rice Maize Other cereals Vegetables one Vegetables two  \
# area(1000 ha)    1 261  452   927           351            388            388
#  Jan 2010           35    0     0            10              0              0
# Feb 2010            35    0     0            10              0              0
# March 2010          35    0     0            10              0              0
# April 2010          35    0     0            10             11              0
#
#                Fruits Mangoes Figs Dates  ... Olives Groundnuts Sesame  \
# area(1000 ha)     389      64   32    42  ...     50         38     28
#  Jan 2010          11       2    1     1  ...      1          0      0
# Feb 2010           11       2    1     1  ...      1          0      0
# March 2010         11       2    1     1  ...      1          0      0
# April 2010         11       2    1     1  ...      1          0      0
#
# ...
