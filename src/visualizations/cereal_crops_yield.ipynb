# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Datasets

# %%
data = pd.read_csv("../data/Final Datasets/Crop related datasets/cereal_crops_yield.csv")
data.head()
# Out:
#    year  barley_hg_ha  maize_hg_ha  rice_paddy_hg_ha  rye_hg_ha  \
# 0  1961         26116        24014             50531        NaN
# 1  1962         26611        26040             58395        NaN
# 2  1963         26488        25824             55062        NaN
# 3  1964         26850        27716             50396        NaN
# 4  1965         24642        40703             50253        NaN
#
#    sorghum_hg_ha  wheat_hg_ha
# 0          35446        24697
# 1          34487        26064
# 2          35911        26425
# 3          35526        27551
# 4          38381        26445

# %% [markdown]
# # EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              59 non-null     int64
#  1   barley_hg_ha      59 non-null     int64
#  2   maize_hg_ha       59 non-null     int64
#  3   rice_paddy_hg_ha  59 non-null     int64
#  4   rye_hg_ha         31 non-null     float64
#  5   sorghum_hg_ha     59 non-null     int64
#  6   wheat_hg_ha       59 non-null     int64
# dtypes: float64(1), int64(6)
# memory usage: 3.4 KB

# %%
data = data.infer_objects()

# %%
data = data.fillna(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              59 non-null     int64
#  1   barley_hg_ha      59 non-null     int64
#  2   maize_hg_ha       59 non-null     int64
#  3   rice_paddy_hg_ha  59 non-null     int64
#  4   rye_hg_ha         59 non-null     float64
#  5   sorghum_hg_ha     59 non-null     int64
#  6   wheat_hg_ha       59 non-null     int64
# dtypes: float64(1), int64(6)
# memory usage: 3.4 KB

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'barley_hg_ha', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'maize_hg_ha', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'rice_paddy_hg_ha', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'rye_hg_ha', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'sorghum_hg_ha', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'wheat_hg_ha', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(data = data)
