# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Excel/infonile-_-story-data-domestic-water-egypt.csv',sep=r'\s*,\s*',
                         header=0, encoding='ascii', engine='python')
df
# Out:
#        Governorate  Surface Water - SW (MCM)  Groundwater - GW (MCM)  \
# 0       Alexandria                    1056.3                     0.0
# 1           Assiut                     112.5                   112.3
# 2            Aswan                     116.3                     2.8
# 3     Bani Souwaif                     195.7                     7.3
# 4            Cairo                    2096.5                     1.8
# 5        Dakahliya                     463.9                    64.8
# 6         Damietta                     188.0                     0.0
# 7       El Beheira                     471.7                    16.7
# 8           Fayoum                     249.1                     0.0
# 9          Gharbya                     196.8                   139.2
# 10            Giza                    1165.5                    69.4
# 11        Ismailia                     139.8                     0.0
# 12  Kafr el-Sheikh                     287.5                     0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 8 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Governorate                         28 non-null     object
#  1   Surface Water - SW (MCM)            28 non-null     float64
#  2   Groundwater - GW (MCM)              28 non-null     float64
#  3   Sea Water Desalination - SWD (MCM)  28 non-null     float64
#  4   Total (MCM)                         28 non-null     float64
#  5   Area (KMS)                          28 non-null     float64
#  6   Population (2015)                   28 non-null     float64
#  7   Population Density (2015)           27 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 1.9+ KB

# %% [markdown]
# ### We can notice that fresh water from salted water *sea water* producing is so low, the total is 21.64 that is neglected beside surface and ground water

# %%
SW = df["Surface Water - SW (MCM)"][27]
GW = df["Groundwater - GW (MCM)"][27]
SWD = df["Sea Water Desalination - SWD (MCM)"][27]
TOT = df['Total (MCM)'][27]
AREA = df['Area (KMS)'][27]
POP = df['Population (2015)'][27]
POP
# Out:
# 87963276.0

# %%
percentage_used=[]
for i in df["Total (MCM)"]:
    percentage_used.append(round(i/TOT,3))

    
Ground=[]
for i in df["Groundwater - GW (MCM)"]:
    Ground.append(round(i/GW,3))

Surface=[]
for i in df["Surface Water - SW (MCM)"]:
    Surface.append(round(i/SW,3))
    
Desalination=[]
for i in df["Sea Water Desalination - SWD (MCM)"]:
    Desalination.append(round(i/SWD,3))
    
Area_perc=[]
for i in df["Area (KMS)"]:
    Area_perc.append(round(i/AREA,3))
    
Pop_perc=[]
for i in df["Population (2015)"]:
    Pop_perc.append(round(i/POP,3))
    
len(Pop_perc)
# Out:
# 28

# %%
df['Total Percentage']=percentage_used
df['SW Percentage']=Surface
df['GW Percentage']=Ground
df['SWD Percentage']=Desalination
df['Area Percentage']=Area_perc
df['Population Percentage']=Pop_perc
df
# Out:
#        Governorate  Surface Water - SW (MCM)  Groundwater - GW (MCM)  \
# 0       Alexandria                    1056.3                     0.0
# 1           Assiut                     112.5                   112.3
# 2            Aswan                     116.3                     2.8
# 3     Bani Souwaif                     195.7                     7.3
# 4            Cairo                    2096.5                     1.8
# 5        Dakahliya                     463.9                    64.8
# 6         Damietta                     188.0                     0.0
# 7       El Beheira                     471.7                    16.7
# 8           Fayoum                     249.1                     0.0
# 9          Gharbya                     196.8                   139.2
# 10            Giza                    1165.5                    69.4
# 11        Ismailia                     139.8                     0.0
# 12  Kafr el-Sheikh                     287.5                     0.0
# ...

# %%
df2 = df.drop(index=27,axis=0)
df2
# Out:
#        Governorate  Surface Water - SW (MCM)  Groundwater - GW (MCM)  \
# 0       Alexandria                    1056.3                     0.0
# 1           Assiut                     112.5                   112.3
# 2            Aswan                     116.3                     2.8
# 3     Bani Souwaif                     195.7                     7.3
# 4            Cairo                    2096.5                     1.8
# 5        Dakahliya                     463.9                    64.8
# 6         Damietta                     188.0                     0.0
# 7       El Beheira                     471.7                    16.7
# 8           Fayoum                     249.1                     0.0
# 9          Gharbya                     196.8                   139.2
# 10            Giza                    1165.5                    69.4
# 11        Ismailia                     139.8                     0.0
# 12  Kafr el-Sheikh                     287.5                     0.0
# ...

# %%
df.describe()
# Out:
#        Surface Water - SW (MCM)  Groundwater - GW (MCM)  \
# count                 28.000000               28.000000
# mean                 585.285714               70.842857
# std                 1556.646152              186.626919
# min                    0.000000                0.000000
# 25%                   90.425000                0.000000
# 50%                  180.850000               11.400000
# 75%                  290.575000               69.975000
# max                 8194.000000              991.800000
#
#        Sea Water Desalination - SWD (MCM)  Total (MCM)          Area  \
# count                           28.000000    28.000000  2.800000e+01
# mean                             1.545714   657.674286  7.217192e+04
# std                              4.584081  1733.745144  2.035802e+05
# min                              0.000000     9.700000  9.100000e+02
# 25%                              0.000000    95.350000  2.938500e+03
# ...

# %%
labels = 'Surface Water', 'Groundwater', 'Sea Water Desalination'
total = [8194.0, 991.8, 21.64]
explode = (0.05, 0, 0)
fig1, ax1 = plt.subplots(figsize=(7.5,7.5))
ax1.pie(total, explode=explode, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')
plt.show()

# %% [markdown]
# ### We can notice like above that the Sea water Desalination is so low compared to others, does that mean is it a problem as an artificial process or what ?

# %%
fig, ax = plt.subplots(figsize=(13,8))
sns.barplot(x=df2['Area Percentage'], y=df2['Governorate'])
# Out:
# <AxesSubplot:xlabel='Area Percentage', ylabel='Governorate'>

# %% [markdown]
# ### New Valley has the biggest size

# %%
fig, ax = plt.subplots(figsize=(13,8))
sns.barplot(x=df2['SW Percentage'], y=df2['Governorate'])
# Out:
# <AxesSubplot:xlabel='SW Percentage', ylabel='Governorate'>

# %% [markdown]
# ### Cairo followed by Giza and Alexandria consume the most surface water, and these are Egypt's top 3 Governorate and more of an industry cities than farming etc...

# %%
fig, ax = plt.subplots(figsize=(13,8))
sns.barplot(x=df2['Total Percentage'], y=df2['Governorate'])
# Out:
# <AxesSubplot:xlabel='Total Percentage', ylabel='Governorate'>

# %% [markdown]
# ### Cairo followed by Giza and Alexandria consume the most water, and these are Egypt's top 3 Governorate and more of an industry cities than farming etc...

# %%
fig, ax = plt.subplots(figsize=(13,8))
sns.barplot(x=df2['GW Percentage'], y=df2['Governorate'])
# Out:
# <AxesSubplot:xlabel='GW Percentage', ylabel='Governorate'>

# %% [markdown]
# ### Some of the Delta's cities and upper Egypt consumes the most Ground water Except Alexandria *as one of the Delta's cities* and Giza here is also an Exception

# %%
fig, ax = plt.subplots(figsize=(13,8))
sns.barplot(x=df2['SWD Percentage'], y=df2['Governorate'])
# Out:
# <AxesSubplot:xlabel='SWD Percentage', ylabel='Governorate'>

# %% [markdown]
# ### South Sinai has the most SWD consumption, how I don't know actually

# %%
df2.sort_values(by='Governorate')
# Out:
#        Governorate  Surface Water - SW (MCM)  Groundwater - GW (MCM)  \
# 0       Alexandria                    1056.3                     0.0
# 1           Assiut                     112.5                   112.3
# 2            Aswan                     116.3                     2.8
# 3     Bani Souwaif                     195.7                     7.3
# 4            Cairo                    2096.5                     1.8
# 5        Dakahliya                     463.9                    64.8
# 6         Damietta                     188.0                     0.0
# 7       El Beheira                     471.7                    16.7
# 8           Fayoum                     249.1                     0.0
# 9          Gharbya                     196.8                   139.2
# 10            Giza                    1165.5                    69.4
# 11        Ismailia                     139.8                     0.0
# 12  Kafr el-Sheikh                     287.5                     0.0
# ...

# %%
fig, ax = plt.subplots(figsize=(13,8))
dfg = df2.groupby(['Governorate'])[['Area Percentage','Total Percentage']].sum()
dfg.plot(ax=ax, kind='bar', lw = 1.5)

#sns.barplot(data=df2, y=df2['Area Percentage'],x=df2['Total Percentage'],hue=df2['Governorate'])
# Out:
# <AxesSubplot:xlabel='Governorate'>

# %% [markdown]
# ### As we can see, there is no relation between Area and Total consumption

# %% [markdown]
# ## All of the data above is about domestic water; that is water for households not farming purposes etc..
# ### There is also an important factor to be considered and is the population, because cities like New Valley with huge area but low consumption, so maybe population has something to do with it
# ### The main source used is Surface water, because of the Nile for sure, but the Sea Water Desalination is so low compared to others, so maybe due to the Dam problems, we can actually try to make the sea water drinkable, since Egypt is surrounded by 2 seas from east and north, so maybe it would help
# ### The problem with Ground water as well, since groundwaters are found in aquifers mainly, some deserts contains aquifers, Egypt has eastern and western Sahara *Desert* Maybe it can actually increase the amount of groundwater to be counted on

# %% [markdown]
# ### I updated the .csv file and added population and population density

# %%
fig, ax = plt.subplots(figsize=(13,8))
sns.barplot(x=df2['Population Percentage'], y=df2['Governorate'])
# Out:
# <AxesSubplot:xlabel='Population Percentage', ylabel='Governorate'>

# %%
fig, ax = plt.subplots(figsize=(13,8))
dfg = df2.groupby(['Governorate'])[['Population Percentage','Total Percentage']].sum().sort_values('Population Percentage', ascending=False)
dfg.plot(ax=ax, kind='bar', lw = 1.5, colormap='flare')
# Out:
# <AxesSubplot:xlabel='Governorate'>

# %% [markdown]
# ### From both of the above, it makes sense that Cairo has the most consumption

# %%
sns.histplot(data = df2, x='Population Percentage', y='Total Percentage')
# Out:
# <AxesSubplot:xlabel='Population Percentage', ylabel='Total Percentage'>

# %%
df2.corr()
# Out:
#                                     Surface Water - SW (MCM)  \
# Surface Water - SW (MCM)                            1.000000
# Groundwater - GW (MCM)                             -0.072655
# Sea Water Desalination - SWD (MCM)                 -0.210534
# Total (MCM)                                         0.994463
# Area (KMS)                                         -0.218257
# Population (2015)                                   0.745718
# Population Density (2015)                           0.447810
# Total Percentage                                    0.994746
# SW Percentage                                       0.999989
# GW Percentage                                      -0.072347
# SWD Percentage                                     -0.210473
# Area Percentage                                    -0.218423
# Population Percentage                               0.744124
#
#                                     Groundwater - GW (MCM)  \
# ...

# %%
fig, ax = plt.subplots(figsize=(13,8))
sns.heatmap(df2.corr(), cmap='Blues',
    annot=True,
    linewidths=1,
    linecolor='black',)
# Out:
# <AxesSubplot:>
