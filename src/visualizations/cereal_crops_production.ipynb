# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Datasets

# %%
data = pd.read_csv("../data/Final Datasets/Crop related datasets/cereal_crops_production.csv")
data.head()
# Out:
#    year  barley_tonnes  maize_tonnes  rice_paddy_tonnes  \
# 0  1961         132910       1617130            1142000
# 1  1962         146296       2003690            2038000
# 2  1963         134362       1867000            2219000
# 3  1964         142174       1934212            2036000
# 4  1965         129606       2141000            1789000
#
#    rice_paddy_rice_milled_equivalent__tonnes  rye_tonnes  sorghum_tonnes  \
# 0                                     761714         NaN          681000
# 1                                    1359346         NaN          658849
# 2                                    1480073         NaN          729000
# 3                                    1358012         NaN          739640
# 4                                    1193263         NaN          806000
#
#    wheat_tonnes
# 0       1435926
# 1       1593098
# 2       1493000
# 3       1499881
# 4       1272000

# %% [markdown]
# # EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 8 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   year                                       59 non-null     int64
#  1   barley_tonnes                              59 non-null     int64
#  2   maize_tonnes                               59 non-null     int64
#  3   rice_paddy_tonnes                          59 non-null     int64
#  4   rice_paddy_rice_milled_equivalent__tonnes  59 non-null     int64
#  5   rye_tonnes                                 31 non-null     float64
#  6   sorghum_tonnes                             59 non-null     int64
#  7   wheat_tonnes                               59 non-null     int64
# dtypes: float64(1), int64(7)
# memory usage: 3.8 KB

# %%
data = data.infer_objects()

# %%
data = data.fillna(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 8 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   year                                       59 non-null     int64
#  1   barley_tonnes                              59 non-null     int64
#  2   maize_tonnes                               59 non-null     int64
#  3   rice_paddy_tonnes                          59 non-null     int64
#  4   rice_paddy_rice_milled_equivalent__tonnes  59 non-null     int64
#  5   rye_tonnes                                 59 non-null     float64
#  6   sorghum_tonnes                             59 non-null     int64
#  7   wheat_tonnes                               59 non-null     int64
# dtypes: float64(1), int64(7)
# memory usage: 3.8 KB

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'barley_tonnes', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'maize_tonnes', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'rice_paddy_tonnes', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'rice_paddy_rice_milled_equivalent__tonnes', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'rye_tonnes', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'sorghum_tonnes', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'wheat_tonnes', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(data = data)
