# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read Datasets

# %%
data = pd.read_csv("../data/Final Datasets/Crop related datasets/harvested_area_of_cereal_crops.csv")
data.head()
# Out:
#    year  barley_ha  maize_ha  rice_paddy_ha  rye_ha  sorghum_ha  wheat_ha
# 0  1961      50892    673399         226000     NaN      192124    581409
# 1  1962      54976    769464         349000     NaN      191042    611226
# 2  1963      50725    722958         403000     NaN      203000    565000
# 3  1964      52951    697858         404000     NaN      208196    544393
# 4  1965      52595    526000         356000     NaN      210000    481000

# %% [markdown]
# # EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           59 non-null     int64
#  1   barley_ha      59 non-null     int64
#  2   maize_ha       59 non-null     int64
#  3   rice_paddy_ha  59 non-null     int64
#  4   rye_ha         31 non-null     float64
#  5   sorghum_ha     59 non-null     int64
#  6   wheat_ha       59 non-null     int64
# dtypes: float64(1), int64(6)
# memory usage: 3.4 KB

# %%
data = data.infer_objects()

# %%
data = data.fillna(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           59 non-null     int64
#  1   barley_ha      59 non-null     int64
#  2   maize_ha       59 non-null     int64
#  3   rice_paddy_ha  59 non-null     int64
#  4   rye_ha         59 non-null     float64
#  5   sorghum_ha     59 non-null     int64
#  6   wheat_ha       59 non-null     int64
# dtypes: float64(1), int64(6)
# memory usage: 3.4 KB

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'barley_ha', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'maize_ha', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'rice_paddy_ha', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'rye_ha', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'sorghum_ha', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(x = 'year', y = 'wheat_ha', data = data)

# %%
plt.figure(figsize = (10,5))
fig = sns.lineplot(data = data)
