# %%
import pandas as pd 
import os
import numpy as np
import re

# %%
df1=pd.read_csv('/content/drive/MyDrive/Omdena Fresh water/Dataset/ UNSD_merged/_استخراج المياه العذبة واستخدامها____________________________________ - Sheet1.csv')

# %%
df2=pd.read_csv('/content/drive/MyDrive/Omdena Fresh water/Dataset/ UNSD_merged/_إنتاج المياه العادمة ومعالجتها _____________________________________ - Sheet1.csv')

# %%
df3=pd.read_csv('/content/drive/MyDrive/Omdena Fresh water/Dataset/ UNSD_merged/_صناعة إمدادات المياه_ - Sheet1.csv')

# %%
df4=pd.read_csv('/content/drive/MyDrive/Omdena Fresh water/Dataset/ UNSD_merged/موارد المياه العذبة المتجددة - Sheet1 (1).csv')

# %%
df1["Category + Unit "] = df1["Cateogry"] + df1["Unit"]
df2["Category + Unit "] = df2["Category"] + df2["Unit"]
df3["Category + Unit "] = df3["Category"] + df3["Unit"]
df4["Category + Unit "] = df4["Category"] + df4["Unit"]

# %%
df1["Category + Unit + ID"] = df1["ID"].astype(str) +" "+ df1["Category + Unit "]
df2["Category + Unit + ID"] = df2["Line"].astype(str) +" "+ df2["Category + Unit "]
df3["Category + Unit + ID"] = df3["Line"].astype(str) +" "+ df3["Category + Unit "]
df4["Category + Unit + ID"] = df4["ID"].astype(str)+" "+ df4["Category + Unit "]

# %%
df2.drop(['Line','Category','Unit','Category + Unit '],inplace=True,axis=1)
df3.drop(['Line','Category','Unit','Category + Unit '],inplace=True,axis=1)
df4.drop(['ID','Category','Unit','Category + Unit '],inplace=True,axis=1)

# %%
df1.drop(['Cateogry','Unit'],inplace=True,axis=1)

# %%
df1.drop(['ID'],inplace=True,axis=1)

# %%
df1.drop(["Category + Unit "],inplace=True,axis=1)

# %%
len(df1)
# Out:
# 33

# %%
df1.head(33)
# Out:
#        1990  1995  ...  2019                               Category + Unit + ID
# 0   54733.0   NaN  ...   NaN        1.0 Fresh surface water abstracted mio m3/y
# 1       NaN   NaN  ...   NaN          2.0 Fresh groundwater abstracted mio m3/y
# 2       NaN   NaN  ...   NaN           3.0 Freshwater abstracted (=1+2)mio m3/y
# 3       NaN   NaN  ...   NaN             4.0 Water returned without usemio m3/y
# 4       NaN   NaN  ...   NaN       5.0 Net freshwater abstracted (=3-4)mio m3/y
# 5       NaN   NaN  ...   NaN                                                NaN
# 6       NaN   NaN  ...   NaN        6.0 Water supply industry (ISIC 36)mio m3/y
# 7       NaN   NaN  ...   NaN                            7.0 Households mio m3/y
# 8       NaN   NaN  ...   NaN  8.0 Agriculture, forestry and fishing (ISIC 01...
# 9       NaN   NaN  ...   NaN  9.0 of which for: \nIrrigation in agriculturem...
# 10      NaN   NaN  ...   NaN     10.0 Mining and quarrying (ISIC 05-09)mio m3/y
# ...

# %%
df1_new=df1.melt(id_vars=["Category + Unit + ID"], 
        var_name="Year", 
        value_name="Value")

# %%
df2_new=df2.melt(id_vars=["Category + Unit + ID"], 
        var_name="Year", 
        value_name="Value")

df3_new=df3.melt(id_vars=["Category + Unit + ID"], 
        var_name="Year", 
        value_name="Value")

df4_new=df4.melt(id_vars=["Category + Unit + ID"], 
        var_name="Year", 
        value_name="Value")

# %%
df1_new.head(20)
# Out:
#                                  Category + Unit + ID  Year    Value
# 0         1.0 Fresh surface water abstracted mio m3/y  1990  54733.0
# 1           2.0 Fresh groundwater abstracted mio m3/y  1990      NaN
# 2            3.0 Freshwater abstracted (=1+2)mio m3/y  1990      NaN
# 3              4.0 Water returned without usemio m3/y  1990      NaN
# 4        5.0 Net freshwater abstracted (=3-4)mio m3/y  1990      NaN
# 5                                                 NaN  1990      NaN
# 6         6.0 Water supply industry (ISIC 36)mio m3/y  1990      NaN
# 7                             7.0 Households mio m3/y  1990      NaN
# 8   8.0 Agriculture, forestry and fishing (ISIC 01...  1990      NaN
# 9   9.0 of which for: \nIrrigation in agriculturem...  1990      NaN
# 10     10.0 Mining and quarrying (ISIC 05-09)mio m3/y  1990      NaN
# 11            11.0 Manufacturing (ISIC 10-33)mio m3/y  1990      NaN
# 12  12.0 Electricity, gas, steam and air condition...  1990      NaN
# ...

# %%
df2_new.head(20)
# Out:
#                                  Category + Unit + ID  Year        Value
# 0               1 Total wastewater generated1000 m3/d  1990          NaN
# 1   2 by:\n       Agriculture, forestry and fishin...  1990          NaN
# 2        3 Mining and quarrying (ISIC 05-09)1000 m3/d  1990          NaN
# 3               4 Manufacturing (ISIC 10-33)1000 m3/d  1990          NaN
# 4   5    Electricity, gas, steam and air condition...  1990          NaN
# 5   6 of which by:\nElectric power generation, tra...  1990          NaN
# 6                7 Construction (ISIC 41-43)1000 m3/d  1990          NaN
# 7                8 Other economic activities1000 m3/d  1990          NaN
# 8                               9 Households1000 m3/d  1990          NaN
# 9   10 Wastewater treated in urban wastewater trea...  1990  5071.200195
# 10       11 Of which:\n    Primary treatment1000 m3/d  1990          NaN
# 11                    12 Secondary treatment1000 m3/d  1990          NaN
# ...

# %%
df1_new
# Out:
#                                   Category + Unit + ID  Year    Value
# 0          1.0 Fresh surface water abstracted mio m3/y  1990  54733.0
# 1            2.0 Fresh groundwater abstracted mio m3/y  1990      NaN
# 2             3.0 Freshwater abstracted (=1+2)mio m3/y  1990      NaN
# 3               4.0 Water returned without usemio m3/y  1990      NaN
# 4         5.0 Net freshwater abstracted (=3-4)mio m3/y  1990      NaN
# ..                                                 ...   ...      ...
# 721        27.0     Manufacturing (ISIC 10-33)mio m3/y  2019      NaN
# 722  28.0     Electricity, gas, steam and air condi...  2019      NaN
# 723  29.0     of which for:\n    Electric power gen...  2019      NaN
# 724             30.0 Construction (ISIC 41-43)mio m3/y  2019      NaN
# 725         31.0     Other economic activitiesmio m3/y  2019      NaN
#
# [726 rows x 3 columns]

# %%
# df1_pivot = df1_new.pivot_table('Value', ['Year'], 'Category + Unit + ID')
df1_pivot= df1_new.pivot_table(index='Year',columns='Category + Unit + ID', values="Value",dropna=False)

# %%
df1_pivot.reset_index( drop=False, inplace=True )

# %%
df2_pivot = df2_new.pivot_table('Value', ['Year'], 'Category + Unit + ID',dropna=False)

# %%
df3_pivot = df3_new.pivot_table('Value', ['Year'], 'Category + Unit + ID',dropna=False)
df4_pivot = df4_new.pivot_table('Value', ['Year'], 'Category + Unit + ID',dropna=False)

# %%
df2_pivot.reset_index( drop=False, inplace=True )
df3_pivot.reset_index( drop=False, inplace=True )
df4_pivot.reset_index( drop=False, inplace=True )

# %%
df1_pivot
# Out:
# Category + Unit + ID  Year  ...  9.0 of which for: \nIrrigation in agriculturemio m3/y
# 0                     1990  ...                                                NaN
# 1                     1995  ...                                                NaN
# 2                     2000  ...                                                NaN
# 3                     2001  ...                                                NaN
# 4                     2002  ...                                                NaN
# 5                     2003  ...                                                NaN
# 6                     2004  ...                                                NaN
# 7                     2005  ...                                                NaN
# 8                     2006  ...                                                NaN
# 9                     2007  ...                                                NaN
# ...

# %%
df1_pivot.columns
# Out:
# Index(['Year', '1.0 Fresh surface water abstracted mio m3/y',
#        '11.0 Manufacturing (ISIC 10-33)mio m3/y',
#        '13.0 of which for:\nElectric power generation, transmission and distribution (ISIC 351)mio m3/y',
#        '16.0 Desalinated watermio m3/y', '17.0 Reused watermio m3/y',
#        '18.0 Imports of watermio m3/y', '19.0 Exports of watermio m3/y',
#        '2.0 Fresh groundwater abstracted mio m3/y',
#        '20.0 Total freshwater available for use (=3+14+15+16-17)mio m3/y',
#        '21.0 Losses during transportmio m3/y',
#        '22.0 Total freshwater use (=18-19)mio m3/y',
#        '23.0     Households mio m3/y',
#        '24.0     Agriculture, forestry and fishing (ISIC 01-03)mio m3/y',
#        '25.0         of which for: \n        Irrigation in agriculturemio m3/y',
#        '27.0     Manufacturing (ISIC 10-33)mio m3/y',
#        '3.0 Freshwater abstracted (=1+2)mio m3/y',
#        '6.0 Water supply industry (ISIC 36)mio m3/y',
# ...

# %%
len(final_df)
# Out:
# 22

# %%
final_df.head(22)
# Out:
# Category + Unit + ID  Year  ...  9 Households1000 m3/d
# 0                     1990  ...                    NaN
# 1                     1995  ...                    NaN
# 2                     2000  ...                    NaN
# 3                     2001  ...                    NaN
# 4                     2002  ...                    NaN
# 5                     2003  ...                    NaN
# 6                     2004  ...                    NaN
# 7                     2005  ...                    NaN
# 8                     2006  ...                    NaN
# 9                     2007  ...                    NaN
# 10                    2008  ...                    NaN
# 11                    2009  ...                    NaN
# 12                    2010  ...                    NaN
# 13                    2011  ...                    NaN
# 14                    2012  ...                    NaN
# 15                    2013  ...                    NaN
# ...

# %%
final_df=pd.merge(df1_pivot, df2_pivot, how="inner", on=["Year"])

# %%
final_df=pd.merge(final_df, df3_pivot, how="inner", on=["Year"])

# %%
final_df=pd.merge(final_df, df4_pivot, how="inner", on=["Year"])

# %%
final_df = final_df[final_df.Year != 'Long term annual average']

# %%
final_df.columns
# Out:
# Index(['Year', '1.0 Fresh surface water abstracted mio m3/y',
#        '10.0 Mining and quarrying (ISIC 05-09)mio m3/y',
#        '11.0 Manufacturing (ISIC 10-33)mio m3/y',
#        '12.0 Electricity, gas, steam and air conditioning supply  (ISIC 35)mio m3/y',
#        '13.0 of which for:\nElectric power generation, transmission and distribution (ISIC 351)mio m3/y',
#        '14.0 Construction (ISIC 41-43)mio m3/y',
#        '15.0 Other economic activitiesmio m3/y',
#        '16.0 Desalinated watermio m3/y', '17.0 Reused watermio m3/y',
#        '18.0 Imports of watermio m3/y', '19.0 Exports of watermio m3/y',
#        '2.0 Fresh groundwater abstracted mio m3/y',
#        '20.0 Total freshwater available for use (=3+14+15+16-17)mio m3/y',
#        '21.0 Losses during transportmio m3/y',
#        '22.0 Total freshwater use (=18-19)mio m3/y',
#        '23.0     Households mio m3/y',
#        '24.0     Agriculture, forestry and fishing (ISIC 01-03)mio m3/y',
# ...

# %%
final_df.Year.unique()
# Out:
# array(['1990', '1995', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019'], dtype=object)

# %%
final_df.head(25)
# Out:
# Category + Unit + ID  Year  ...  9 Outflow of surface and groundwaters to the seamio m3/y
# 0                     1990  ...                                                NaN
# 1                     1995  ...                                                NaN
# 2                     2000  ...                                                NaN
# 3                     2001  ...                                                NaN
# 4                     2002  ...                                                NaN
# 5                     2003  ...                                               0.00
# 6                     2004  ...                                                NaN
# 7                     2005  ...                                                NaN
# 8                     2006  ...                                                NaN
# 9                     2007  ...                                                NaN
# ...

# %%
final_df.to_csv('/content/drive/MyDrive/Omdena Fresh water/Dataset/ UNSD_merged/merged_UNSD_index_false.csv',index=False)

# %%
final_df.to_csv('/content/drive/MyDrive/Omdena Fresh water/Dataset/ UNSD_merged/merged_UNSD_index_true.csv',index=True)

# %%
df2_pivot.to_csv('/content/drive/MyDrive/Omdena Fresh water/Dataset/ UNSD_merged/file_2.csv',index=False)
df1_pivot.to_csv('/content/drive/MyDrive/Omdena Fresh water/Dataset/ UNSD_merged/file_1.csv',index=False)
df3_pivot.to_csv('/content/drive/MyDrive/Omdena Fresh water/Dataset/ UNSD_merged/file_3.csv',index=False)
df4_pivot.to_csv('/content/drive/MyDrive/Omdena Fresh water/Dataset/ UNSD_merged/file_4.csv',index=False)
