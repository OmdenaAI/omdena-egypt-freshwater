# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('/content/drive/MyDrive/Omdena Fresh water/Dataset/موارد المياه العذبة المتجددة - Sheet1.csv')

# %%
df.head()
# Out:
#    الخط                                              الفئة  ... 2018  2019
# 0     1                                             الهطول  ...  NaN   NaN
# 1     2                                       البخر الفعلي  ...  NaN   NaN
# 2     3                              التدفق الداخلي =)1-2(  ...  NaN   NaN
# 3     4  التدفق الداخل للمياه السطحية والمياه الجوفية م...  ...  NaN   NaN
# 4     5                موارد المياه العذبة المتجددة =)3+4(  ...  NaN   NaN
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['الخط', 'الفئة', 'الوحدة', 'المتوسط السنوي في الأجل الطويل', '1990',
#        '1995', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019'],
#       dtype='object')

# %%
df['الفئة'].unique()
# Out:
# array(['الهطول', 'البخر الفعلي', 'التدفق الداخلي =)1-2(',
#        'التدفق الداخل للمياه السطحية والمياه الجوفية من البلدان المجاورة',
#        'موارد المياه العذبة المتجددة =)3+4(',
#        'التدفقات الخارجة للمياه السطحية والمياه الجوفية إلى البلدان المجاورة',
#        ' ومنها:\n     المكفول بمعاهدات', '     غير المكفول بمعاهدات',
#        'التدفق الخارج للمياه السطحية والمياه الجوفية إلى البحار'],
#       dtype=object)

# %%
Precipitation_df=df.loc[df['الفئة']=='الهطول' ]

# %%
Precipitation_df.head()
# Out:
#    الخط   الفئة                   الوحدة  ...  2017  2018  2019
# 0     1  الهطول  مليون متر مكعب في السنة  ...   NaN   NaN   NaN
#
# [1 rows x 26 columns]

# %%
Actual_evapotranspiration_df=df.loc[df['الفئة']=='البخر الفعلي' ]

# %%
Actual_evapotranspiration_df
# Out:
#    الخط         الفئة                   الوحدة  ...  2017  2018  2019
# 1     2  البخر الفعلي  مليون متر مكعب في السنة  ...   NaN   NaN   NaN
#
# [1 rows x 26 columns]
